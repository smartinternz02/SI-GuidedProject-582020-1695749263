# %% [markdown]
# **AI ML SMARTBRIDGE EXTERNSHIP 2023**
#
# M Aadhith

# %% [markdown]
# **Importing libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
import matplotlib
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import warnings

# %%
warnings.filterwarnings('ignore')           #ignoring warnings

# %% [markdown]
# **Task 1 - Downloading Dataset** from "https://drive.google.com/file/d/1AvRp8hOK-O76WIFvPj_rk10fAZbt8nWH/view?usp=sharing"\
# Penguin Classification Analysis

# %% [markdown]
# **Task 2 - Loading and displaying data**

# %%
data = pd.read_csv("C:\\Users\\Aadhith\\Downloads\\penguins_size.csv")
data
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
data.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
data.head(10)
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
# 5  Adelie  Torgersen              39.3             20.6              190.0
# 6  Adelie  Torgersen              38.9             17.8              181.0
# 7  Adelie  Torgersen              39.2             19.6              195.0
# 8  Adelie  Torgersen              34.1             18.1              193.0
# 9  Adelie  Torgersen              42.0             20.2              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# ...

# %%
data.tail()
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe               NaN              NaN                NaN
# 340  Gentoo  Biscoe              46.8             14.3              215.0
# 341  Gentoo  Biscoe              50.4             15.7              222.0
# 342  Gentoo  Biscoe              45.2             14.8              212.0
# 343  Gentoo  Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE

# %%
data.tail(10)
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 334  Gentoo  Biscoe              46.2             14.1              217.0
# 335  Gentoo  Biscoe              55.1             16.0              230.0
# 336  Gentoo  Biscoe              44.5             15.7              217.0
# 337  Gentoo  Biscoe              48.8             16.2              222.0
# 338  Gentoo  Biscoe              47.2             13.7              214.0
# 339  Gentoo  Biscoe               NaN              NaN                NaN
# 340  Gentoo  Biscoe              46.8             14.3              215.0
# 341  Gentoo  Biscoe              50.4             15.7              222.0
# 342  Gentoo  Biscoe              45.2             14.8              212.0
# 343  Gentoo  Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 334       4375.0  FEMALE
# 335       5850.0    MALE
# 336       4875.0       .
# 337       6000.0    MALE
# ...

# %% [markdown]
# **Data Preprocessing :**

# %%
data.shape
# Out:
# (344, 7)

# %%
data.size
# Out:
# 2408

# %%
data.isnull()
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0      False   False             False            False              False
# 1      False   False             False            False              False
# 2      False   False             False            False              False
# 3      False   False              True             True               True
# 4      False   False             False            False              False
# ..       ...     ...               ...              ...                ...
# 339    False   False              True             True               True
# 340    False   False             False            False              False
# 341    False   False             False            False              False
# 342    False   False             False            False              False
# 343    False   False             False            False              False
#
#      body_mass_g    sex
# 0          False  False
# ...

# %%
data.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
data.info
# Out:
# <bound method DataFrame.info of     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
data.dtypes
# Out:
# species               object
# island                object
# culmen_length_mm     float64
# culmen_depth_mm      float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
data.duplicated
# Out:
# <bound method DataFrame.duplicated of     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=344, step=1)

# %%
data.columns
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %% [markdown]
# **Task 3 - Performing Visualizations**

# %% [markdown]
# **Univariate Visualizations**

# %%
data.culmen_length_mm.plot()
# Out:
# <Axes: >

# %%
data.culmen_depth_mm.plot()
# Out:
# <Axes: >

# %%
data.flipper_length_mm.plot()
# Out:
# <Axes: >

# %%
data.body_mass_g.plot()
# Out:
# <Axes: >

# %%
sns.distplot(data.culmen_length_mm)
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='Density'>

# %%
sns.distplot(data.culmen_depth_mm)
# Out:
# <Axes: xlabel='culmen_depth_mm', ylabel='Density'>

# %%
sns.distplot(data.flipper_length_mm)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.distplot(data.body_mass_g)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
sns.histplot(data=data, x='flipper_length_mm', bins=20, kde=True)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=data, x='culmen_length_mm', bins=20, kde=True)
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='Count'>

# %%
sns.histplot(data=data, x='culmen_depth_mm', bins=20, kde=True)
# Out:
# <Axes: xlabel='culmen_depth_mm', ylabel='Count'>

# %%
sns.histplot(data=data, x='body_mass_g', bins=20, kde=True)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
colors = ['#ff9999','#66b3ff','#99ff99']
explode = (0.05,0.05,0.05)

fig1, ax1 = plt.subplots()

species_counts = data['species'].value_counts()

plt.pie(species_counts, colors = colors, labels=species_counts.index, autopct='%1.1f%%', startangle=90, pctdistance=0.85, explode = explode)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
sns.pairplot(data)

# %% [markdown]
# **Bivariate Analysis**

# %%
plt.figure(figsize=(8, 8))
sns.boxplot(data=data, x='species', y='culmen_length_mm')
plt.title('Box Plot of Culmen Length by Species')
plt.xlabel('Species')
plt.ylabel('Culmen Length (mm)')
plt.show()

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(data=data, x='culmen_length_mm', y='culmen_depth_mm', hue='species')
plt.title('Scatter Plot of Culmen Length vs. Culmen Depth by Species')
plt.xlabel('Culmen Length (mm)')
plt.ylabel('Culmen Depth (mm)')
plt.show()

# %%
sns.pairplot(data, hue='species', markers=["o", "s", "D"], diag_kind='kde')
plt.suptitle('Pair Plot of Penguin Features by Species')
plt.show()

# %% [markdown]
# **Multivariate**

# %%
correlation_matrix = data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='plasma', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Aadhith\Desktop\Smartbridge\Assignment3.ipynb Cell 45 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Aadhith/Desktop/Smartbridge/Assignment3.ipynb#X63sZmlsZQ%3D%3D?line=0'>1</a> correlation_matrix = data.corr()
#       <a href='vscode-notebook-cell:/c%3A/Users/Aadhith/Desktop/Smartbridge/Assignment3.ipynb#X63sZmlsZQ%3D%3D?line=1'>2</a> plt.figure(figsize=(10, 8))
#       <a href='vscode-notebook-cell:/c%3A/Users/Aadhith/Desktop/Smartbridge/Assignment3.ipynb#X63sZmlsZQ%3D%3D?line=2'>3</a> sns.heatmap(correlation_matrix, annot=True, cmap='plasma', linewidths=0.5)
#
# File c:\Users\Aadhith\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# ...

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=data, x='species', y='flipper_length_mm', hue='sex')
plt.title('Violin Plot of Flipper Length by Species and Sex')
plt.xlabel('Species')
plt.ylabel('Flipper Length (mm)')
plt.show()

# %%
sns.FacetGrid(data, hue="species", height=6) \
   .map(sns.kdeplot, "flipper_length_mm", shade=True) \
   .add_legend()

# %% [markdown]
# **Task 4 - Performing descriptive statistics on the dataset**

# %%
description = data.describe().T.style.background_gradient(
    cmap='viridis',  # colormap
    low=0, high=1,   # range of colors for the gradient
    axis=None        # gradient across the entire DataFrame
)

# styling attributes
description.set_properties(**{'font-size': '10pt', 'text-align': 'center'}).bar(subset=['mean'], color='#FFA07A')
# Out:
# <style type="text/css">
# #T_ae146_row0_col0, #T_ae146_row1_col0, #T_ae146_row2_col0, #T_ae146_row3_col0 {
#   background-color: #460a5d;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
# }
# #T_ae146_row0_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #FFA07A 1.0%, transparent 1.0%);
# }
# #T_ae146_row0_col2, #T_ae146_row0_col3, #T_ae146_row0_col4, #T_ae146_row0_col5, #T_ae146_row0_col6, #T_ae146_row1_col2, #T_ae146_row1_col3, #T_ae146_row1_col4, #T_ae146_row1_col5, #T_ae146_row1_col6, #T_ae146_row1_col7, #T_ae146_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
# }
# #T_ae146_row0_col7 {
#   background-color: #440256;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
# }
# #T_ae146_row1_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
#   font-size: 10pt;
# ...

# %% [markdown]
# **Task 5 - Checking for Missing values and dealing with them**

# %%
data.isnull()
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0      False   False             False            False              False
# 1      False   False             False            False              False
# 2      False   False             False            False              False
# 3      False   False              True             True               True
# 4      False   False             False            False              False
# ..       ...     ...               ...              ...                ...
# 339    False   False              True             True               True
# 340    False   False             False            False              False
# 341    False   False             False            False              False
# 342    False   False             False            False              False
# 343    False   False             False            False              False
#
#      body_mass_g    sex
# 0          False  False
# ...

# %%
data.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
# Columns for which you want to fill null values with mean
selected_columns = ['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm', 'body_mass_g']

# Calculate the mean for the selected columns
mean_values = data[selected_columns].mean()

# Fill null values with the mean for the selected columns
data[selected_columns] = data[selected_columns].fillna(mean_values)

# Calculate the mode of column1
mode_value = data['sex'].mode()[0]

# Fill empty fields in column1 with its mode
data['sex'].fillna(mode_value, inplace=True)

# Print the updated DataFrame
data
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen          39.10000         18.70000         181.000000
# 1    Adelie  Torgersen          39.50000         17.40000         186.000000
# 2    Adelie  Torgersen          40.30000         18.00000         195.000000
# 3    Adelie  Torgersen          43.92193         17.15117         200.915205
# 4    Adelie  Torgersen          36.70000         19.30000         193.000000
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe          43.92193         17.15117         200.915205
# 340  Gentoo     Biscoe          46.80000         14.30000         215.000000
# 341  Gentoo     Biscoe          50.40000         15.70000         222.000000
# 342  Gentoo     Biscoe          45.20000         14.80000         212.000000
# 343  Gentoo     Biscoe          49.90000         16.10000         213.000000
#
#      body_mass_g     sex
# ...

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %% [markdown]
# **Task 6 - Finding the outliers and replacing them**

# %%
data
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen          39.10000         18.70000         181.000000
# 1    Adelie  Torgersen          39.50000         17.40000         186.000000
# 2    Adelie  Torgersen          40.30000         18.00000         195.000000
# 3    Adelie  Torgersen          43.92193         17.15117         200.915205
# 4    Adelie  Torgersen          36.70000         19.30000         193.000000
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe          43.92193         17.15117         200.915205
# 340  Gentoo     Biscoe          46.80000         14.30000         215.000000
# 341  Gentoo     Biscoe          50.40000         15.70000         222.000000
# 342  Gentoo     Biscoe          45.20000         14.80000         212.000000
# 343  Gentoo     Biscoe          49.90000         16.10000         213.000000
#
#      body_mass_g     sex
# ...

# %%
Q1 = data[['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm', 'body_mass_g']].quantile(0.25)
Q3 = data[['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm', 'body_mass_g']].quantile(0.75)
IQR = Q3 - Q1

def replace_outliers(column):
    lower_bound = Q1[column] - 1.5 * IQR[column]
    upper_bound = Q3[column] + 1.5 * IQR[column]
    data[column] = np.where((data[column] < lower_bound) | (data[column] > upper_bound), data[column].median(), data[column])

columns_with_outliers = ['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm', 'body_mass_g']
for column in columns_with_outliers:
    replace_outliers(column)

# %% [markdown]
# **Task 7 - Checking the correlation of independent variables with the target**

# %%
correlation = data[['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm', 'body_mass_g']].corr()
target_correlation = correlation['body_mass_g']
target_correlation
# Out:
# culmen_length_mm     0.595110
# culmen_depth_mm     -0.471916
# flipper_length_mm    0.871202
# body_mass_g          1.000000
# Name: body_mass_g, dtype: float64

# %%
covariance = data[['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm', 'body_mass_g']].cov()
covariance
# Out:
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm          29.633252        -2.519457          50.082029
# culmen_depth_mm           -2.519457         3.877069         -16.118414
# flipper_length_mm         50.082029       -16.118414         196.578837
# body_mass_g             2590.398957      -743.012250        9767.130837
#
#                      body_mass_g
# culmen_length_mm     2590.398957
# culmen_depth_mm      -743.012250
# flipper_length_mm    9767.130837
# body_mass_g        639381.041890

# %% [markdown]
# **Task 8 - Checking for categorical columns and performing encoding**

# %%
le = LabelEncoder()

categorical_columns = ['species', 'island', 'sex']
for column in categorical_columns:
    data[column] = le.fit_transform(data[column])

# %%
data
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0          0       2          39.10000         18.70000         181.000000
# 1          0       2          39.50000         17.40000         186.000000
# 2          0       2          40.30000         18.00000         195.000000
# 3          0       2          43.92193         17.15117         200.915205
# 4          0       2          36.70000         19.30000         193.000000
# ..       ...     ...               ...              ...                ...
# 339        2       0          43.92193         17.15117         200.915205
# 340        2       0          46.80000         14.30000         215.000000
# 341        2       0          50.40000         15.70000         222.000000
# 342        2       0          45.20000         14.80000         212.000000
# 343        2       0          49.90000         16.10000         213.000000
#
#      body_mass_g  sex
# 0    3750.000000    2
# ...

# %% [markdown]
# **Task 9 - Splitting the data into dependent and independent variables**

# %%
X = data.drop('species', axis=1)  # Independent variables
y = data['species']  # Dependent variable

# %% [markdown]
# **Task 10 - Scaling the data**

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# **Task 11 - Splitting the data into training and testing**

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# **Task 12 - Checking the training and testing data shape**

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (275, 6)
# y_train shape: (275,)
# X_test shape: (69, 6)
# y_test shape: (69,)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.96

# %%
plt.plot(y_pred, label='Predicted')
plt.plot(y_test, label='Actual')
plt.legend()
plt.show()
