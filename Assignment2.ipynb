# %% [markdown]
# 21BAI1192 M Aadhith
#
# SmartInternz Assignment 2
#
# Dataset used : House Price India.csv

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#TASK-1: DOWNLOAD DATASET
#Local Storage path: "C:\Users\Aadhith\Downloads\House Price India.csv"

# %%
#TASK-2:LOAD DATASET
df=pd.read_csv("C:\\Users\\Aadhith\\Downloads\\House Price India.csv")
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
df.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
#TASK-3: EDA

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
sns.displot(df.Date)

# %%
sns.displot(df.Date)

# %%
plt.plot(df['number of bathrooms'],label='bathrooms',linewidth=1)
plt.plot(df['number of bedrooms'],label='bedrooms',linewidth=1)
plt.plot(df['number of floors'],label='floors',linewidth=1)
plt.legend()
plt.show()

# %%
sns.barplot(x =df.Date.value_counts().index,y =df.Date.value_counts())
# Out:
# <Axes: xlabel='Date', ylabel='count'>

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
sns.scatterplot(x=df.Date,y=df.Price)
plt.show()

# %%
sns.lineplot(x=df.Date,y=df.Price)
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
sns.lineplot(x=df['Area of the basement'],y=df.Price,label='Basement')
sns.lineplot(x=df['Area of the house(excluding basement)'],y=df.Price,label='House')
# Out:
# <Axes: xlabel='Area of the basement', ylabel='Price'>

# %% [markdown]
# MULTIVARIATE ANALYSIS

# %%
sns.heatmap(df.corr(),annot=True)
plt.xticks(rotation=90)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5,
#         22.5]),
#  [Text(0.5, 0, 'id'),
#   Text(1.5, 0, 'Date'),
#   Text(2.5, 0, 'number of bedrooms'),
#   Text(3.5, 0, 'number of bathrooms'),
#   Text(4.5, 0, 'living area'),
#   Text(5.5, 0, 'lot area'),
#   Text(6.5, 0, 'number of floors'),
#   Text(7.5, 0, 'waterfront present'),
#   Text(8.5, 0, 'number of views'),
#   Text(9.5, 0, 'condition of the house'),
#   Text(10.5, 0, 'grade of the house'),
#   Text(11.5, 0, 'Area of the house(excluding basement)'),
#   Text(12.5, 0, 'Area of the basement'),
#   Text(13.5, 0, 'Built Year'),
#   Text(14.5, 0, 'Renovation Year'),
#   Text(15.5, 0, 'Postal Code'),
#   Text(16.5, 0, 'Lattitude'),
#   Text(17.5, 0, 'Longitude'),
#   Text(18.5, 0, 'living_area_renov'),
#   Text(19.5, 0, 'lot_area_renov'),
#   Text(20.5, 0, 'Number of schools nearby'),
# ...

# %%
#TASK-4: DESCRIPTIVE STATISTICS
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
#TASK-5: NULL VALUES
df.isnull().any()
# Out:
# id                                       False
# Date                                     False
# number of bedrooms                       False
# number of bathrooms                      False
# living area                              False
# lot area                                 False
# number of floors                         False
# waterfront present                       False
# number of views                          False
# condition of the house                   False
# grade of the house                       False
# Area of the house(excluding basement)    False
# Area of the basement                     False
# Built Year                               False
# Renovation Year                          False
# Postal Code                              False
# Lattitude                                False
# Longitude                                False
# living_area_renov                        False
# lot_area_renov                           False
# ...

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %% [markdown]
# There are no null values in the dataset
